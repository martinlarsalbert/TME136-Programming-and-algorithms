# %%
# %matplotlib inline
import pandas as pd
import os
import re
import shutil
import numpy as np
import warnings

# %%
df = pd.read_csv('students.csv', sep=';')

# %%
df
# Out:
#     family name          name
# 0      Falkhage      Cornelia
# 1       Fällman        Amanda
# 2         Feldt          Axel
# 3        Flodin        Samuel
# 4        Florin           Ida
# 5     Forssgren          Anna
# 6      Forssmed          Elsa
# 7   Fredriksson       Mathias
# 8       Fröberg       Vincent
# 9       Furborg          Sara
# 10       Gelang        Hampus
# 11        Ghazy  Zahran Saeed
# 12      Görling          Carl
# 13        Graad       Matilda
# 14   Gunnarsson          Adam
# 15   Gustafsson        Amanda
# 16   Gustafsson     Karl-Axel
# 17   Gustafsson          Måns
# 18   Gustafsson       William
# 19      Haapalo         Oskar
# 20     Hallbäck          Hans
# 21       Haller        Gustav
# 22      Hansson       Fredrik
# 23       Hässel        Gustav
# 24      Helland        Wilmer

# %%
regexp=re.compile(r'^ *(.*)')
def clean_names(name):
    result=regexp.search(name)
    return result.group(1)

# %%
df['name']=df['name'].apply(func=clean_names)

# %%
def full_name(row):
    return '%s %s' % (row['name'],row['family name'])

# %%
df.index = df.apply(func=full_name, axis=1)
assert df.index.is_unique

# %%
def create_folder(row,root_path='assignments'):
    
    family_name = row['family name']
    name = row['name']
    dir_name = '%s_%s' % (family_name,name)
    path = os.path.abspath(os.path.join(root_path,dir_name))
    if not os.path.exists(path):
        os.mkdir(path)
    
    return path

# %% [markdown]
# ## Create folders:

# %%
root_path='assignments'

if not os.path.exists(root_path):
    os.mkdir(root_path)

df['dir_path'] = df.apply(func=create_folder, axis=1, root_path=root_path)

# %%
def make_clickable(val):
    s=r'file:///' + val
    return '<a href="{}">{}</a>'.format(s,"path")

# %%
def show(df):
    return df.style.format({'dir_path': make_clickable})

# %% [markdown]
# ## Sort the assignment files into each student folder
# the files from Canvas look something like: *falkhagecornelia_63854_1658103_student_AutomaticGearbox.m*

# %%
df['code name'] = df.apply(lambda x:x['family name'].lower()+x['name'].lower(), axis=1)

# %%
file_name = 'falkhagecornelia_63854_1658103_student_AutomaticGearbox.m'
regexp = re.compile(pattern=r'([^_]+)_\d+_\d+_(.+)')
regexp.search(file_name).group(1)
# Out:
# 'falkhagecornelia'

# %%
regexp.search(file_name).group(2)
# Out:
# 'student_AutomaticGearbox.m'

# %%
submission_dir = 'submissions/'
files = os.listdir(submission_dir)
df_files = pd.DataFrame()

for file_name in files:
    s = pd.Series(dtype='object')
    result = regexp.search(file_name)
    s['code name'] = result.group(1)
    s['file name'] = result.group(2)
    s['original file name'] = file_name
    df_files = df_files.append(s, ignore_index=True)

# %%
df_files.head()
# Out:
#        code name                             file name  \
# 0    ahagenalbin  DragsterAssignment_Albin_Ahagen.docx
# 1    ahagenalbin            student_AutomaticGearbox.m
# 2  albertssontim       Rapport inlämningsuppgift 1.pdf
# 3  albertssontim            student_AutomaticGearbox.m
# 4  albertssontim          student_AutomaticGearbox.asv
#
#                                   original file name
# 0  ahagenalbin_61667_1658733_DragsterAssignment_A...
# 1  ahagenalbin_61667_1658734_student_AutomaticGea...
# 2  albertssontim_60948_1650158_Rapport inlämnings...
# 3  albertssontim_60948_1650159_student_AutomaticG...
# 4  albertssontim_60948_1650160_student_AutomaticG...

# %%
df_files=pd.merge(left=df, right=df_files, how='outer', left_on='code name', right_on='code name').dropna(subset=['family name'])

# %%
df_files.tail()
# Out:
#    family name     name                                           dir_path  \
# 45     Hansson  Fredrik  E:\dev\TME136-Programming-and-algorithms\2021\...
# 46      Hässel   Gustav  E:\dev\TME136-Programming-and-algorithms\2021\...
# 47      Hässel   Gustav  E:\dev\TME136-Programming-and-algorithms\2021\...
# 48      Hässel   Gustav  E:\dev\TME136-Programming-and-algorithms\2021\...
# 49     Helland   Wilmer  E:\dev\TME136-Programming-and-algorithms\2021\...
#
#          code name                               file name  \
# 45  hanssonfredrik              student_AutomaticGearbox.m
# 46    hässelgustav                        bilhastighet-1.m
# 47    hässelgustav              student_AutomaticGearbox.m
# 48    hässelgustav                Inlämmning caster.pages
# 49   hellandwilmer  Automatic gearbox - Wilmer Helland.pdf
#
#                                    original file name
# 45  hanssonfredrik_61305_1652063_student_Automatic...
# 46        hässelgustav_57869_1653071_bilhastighet-1.m
# 47  hässelgustav_57869_1653072_student_AutomaticGe...
# 48  hässelgustav_57869_1653073_Inlämmning caster....
# 49  hellandwilmer_61398_1657862_Automatic gearbox ...

# %% [markdown]
# ### copy the files for each student

# %%
def move_assignment_file_to_student_folder_with_correct_file_name(row, submission_dir):
    
    if pd.isnull(row['original file name']):
        return
    
    src=os.path.join(submission_dir, row['original file name'])
    dst=os.path.join(row['dir_path'],row['file name'])
    
    if not os.path.exists(dst):
        shutil.copyfile(src,dst)

# %%
df_files.apply(move_assignment_file_to_student_folder_with_correct_file_name, submission_dir=submission_dir, axis=1);

# %% [markdown]
# ## Check exist: *student_AutomaticGearbox.m*

# %%
run_file_name='student_AutomaticGearbox.m'
def has_run_file(row, run_file_name='student_AutomaticGearbox.m'):
    path=os.path.join(row['dir_path'],run_file_name)
    return os.path.exists(path)

# %%
def recreate_run_file(row):
    files = os.listdir(row['dir_path'])
    for file in files:
        name,ext = os.path.splitext(file)
        if ext=='.m':
            if 'student_AutomaticGearbox' in file:
                src=os.path.join(row['dir_path'],file)
                dst=os.path.join(row['dir_path'],'student_AutomaticGearbox.m')
                if not os.path.exists(dst):
                    shutil.copyfile(src,dst)

# %%
df['has_run_file'] = df.apply(func=has_run_file, axis=1)

# %%
mask = ~df['has_run_file']
df.loc[mask].apply(func=recreate_run_file, axis=1)
# Out:
# Zahran Saeed Ghazy      None
# Karl-Axel Gustafsson    None
# Hans Hallbäck           None
# Wilmer Helland          None
# dtype: object

# %%
show(df.loc[mask])
# Out:
# <style type="text/css">
# </style>
# <table id="T_1f2dd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >family name</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >dir_path</th>
#       <th class="col_heading level0 col3" >code name</th>
#       <th class="col_heading level0 col4" >has_run_file</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f2dd_level0_row0" class="row_heading level0 row0" >Zahran Saeed Ghazy</th>
#       <td id="T_1f2dd_row0_col0" class="data row0 col0" >Ghazy</td>
#       <td id="T_1f2dd_row0_col1" class="data row0 col1" >Zahran Saeed</td>
#       <td id="T_1f2dd_row0_col2" class="data row0 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Ghazy_Zahran Saeed">path</a></td>
#       <td id="T_1f2dd_row0_col3" class="data row0 col3" >ghazyzahran saeed</td>
#       <td id="T_1f2dd_row0_col4" class="data row0 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1f2dd_level0_row1" class="row_heading level0 row1" >Karl-Axel Gustafsson</th>
#       <td id="T_1f2dd_row1_col0" class="data row1 col0" >Gustafsson</td>
#       <td id="T_1f2dd_row1_col1" class="data row1 col1" >Karl-Axel</td>
#       <td id="T_1f2dd_row1_col2" class="data row1 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Gustafsson_Karl-Axel">path</a></td>
#       <td id="T_1f2dd_row1_col3" class="data row1 col3" >gustafssonkarl-axel</td>
#       <td id="T_1f2dd_row1_col4" class="data row1 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1f2dd_level0_row2" class="row_heading level0 row2" >Hans Hallbäck</th>
#       <td id="T_1f2dd_row2_col0" class="data row2 col0" >Hallbäck</td>
#       <td id="T_1f2dd_row2_col1" class="data row2 col1" >Hans</td>
#       <td id="T_1f2dd_row2_col2" class="data row2 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Hallbäck_Hans">path</a></td>
#       <td id="T_1f2dd_row2_col3" class="data row2 col3" >hallbäckhans</td>
#       <td id="T_1f2dd_row2_col4" class="data row2 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1f2dd_level0_row3" class="row_heading level0 row3" >Wilmer Helland</th>
#       <td id="T_1f2dd_row3_col0" class="data row3 col0" >Helland</td>
#       <td id="T_1f2dd_row3_col1" class="data row3 col1" >Wilmer</td>
#       <td id="T_1f2dd_row3_col2" class="data row3 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Helland_Wilmer">path</a></td>
#       <td id="T_1f2dd_row3_col3" class="data row3 col3" >hellandwilmer</td>
#       <td id="T_1f2dd_row3_col4" class="data row3 col4" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Running the scripts to get the times

# %%
def runner(row, eng):
    
    print('evaluate: %s %s' % (row['name'],row['family name']))
    run_script_name = 'student_AutomaticGearbox.m'
    
    if os.path.exists(run_script_name):
        os.remove(run_script_name)  # Remove old.
    
    assert not os.path.exists(run_script_name)
    
    for file in os.listdir(row['dir_path']):
        ext = os.path.splitext(file)[-1]
        if ext=='.m' or ext=='.mat':
            src=os.path.join(row['dir_path'],file)
            dst=file
            shutil.copyfile(src,dst)
    
    assert os.path.exists(run_script_name)
    
    r = eng.runner()
    finishing_time=r.pop('finishing_time')
    result = r
    #finishing_time=result['TimeTotal'][0][-1]
    return finishing_time

# %% [markdown]
# This one got stuck in an infinite loop beacuse Throttle is not set. **"Warning: You aren't pressing the throttle. This will stop the car. A car that is stationary won't win dragraces. You
# are probably watching the simulation stuck in an infinite loop right now "**

# %%
def manual(full_name:str, ok:bool, comment:str, finishing_time=None):
    df.loc[full_name,'ok'] = ok
    df.loc[full_name,'manual'] = True
    df.loc[full_name,'comment'] = comment
    df.loc[full_name,'finishing_time'] = finishing_time

# %%
#manual(full_name='Emelie Gillerstedt', ok=False, 
#       comment='This one got stuck in an infinite loop beacuse Throttle is not set')
#
#manual(full_name='Rasmus Fischer', ok=False, 
#       comment='Incomplete if clause if, elseif but no else')
#
#

# %%
import matlab.engine
eng = matlab.engine.start_matlab()

for index, row in df.iterrows():
    
    if 'manual' in row:
        if row['manual'] is True:
            print('(Handled manually)')
            continue  # This one is handled manually
    
    if 'ok' in row:
        if row['ok'] is True:
            print('(ok, already checked)')
            continue
    
    try:
        finishing_time = runner(row=row, eng=eng)
    except Exception as e:
        fail = True
        df.loc[index,'finishing_time'] = np.NaN
        print('Fail!')
    else:
        fail = False
        df.loc[index,'finishing_time'] = finishing_time
        df.loc[index,'ok'] = True
            
eng.quit()
# Out:
# evaluate: Cornelia Falkhage
# evaluate: Amanda Fällman
# evaluate: Axel Feldt
# evaluate: Samuel Flodin
# evaluate: Ida Florin
# evaluate: Anna Forssgren
# evaluate: Elsa Forssmed
# evaluate: Mathias Fredriksson
# evaluate: Vincent Fröberg
# evaluate: Sara Furborg
# evaluate: Hampus Gelang
# evaluate: Zahran Saeed Ghazy
# Fail!
# evaluate: Carl Görling
# evaluate: Matilda Graad
# evaluate: Adam Gunnarsson
# evaluate: Amanda Gustafsson
# evaluate: Karl-Axel Gustafsson
# Fail!
# evaluate: Måns Gustafsson
# evaluate: William Gustafsson
# evaluate: Oskar Haapalo
# evaluate: Hans Hallbäck
# Fail!
# evaluate: Gustav Haller
# evaluate: Fredrik Hansson
# evaluate: Gustav Hässel
# evaluate: Wilmer Helland
# Fail!

# %%
eng.quit()

# %%
show(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d0c46_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >family name</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >dir_path</th>
#       <th class="col_heading level0 col3" >code name</th>
#       <th class="col_heading level0 col4" >has_run_file</th>
#       <th class="col_heading level0 col5" >finishing_time</th>
#       <th class="col_heading level0 col6" >ok</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0c46_level0_row0" class="row_heading level0 row0" >Cornelia Falkhage</th>
#       <td id="T_d0c46_row0_col0" class="data row0 col0" >Falkhage</td>
#       <td id="T_d0c46_row0_col1" class="data row0 col1" >Cornelia</td>
#       <td id="T_d0c46_row0_col2" class="data row0 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Falkhage_Cornelia">path</a></td>
#       <td id="T_d0c46_row0_col3" class="data row0 col3" >falkhagecornelia</td>
#       <td id="T_d0c46_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_d0c46_row0_col5" class="data row0 col5" >15.531188</td>
#       <td id="T_d0c46_row0_col6" class="data row0 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row1" class="row_heading level0 row1" >Amanda Fällman</th>
#       <td id="T_d0c46_row1_col0" class="data row1 col0" >Fällman</td>
#       <td id="T_d0c46_row1_col1" class="data row1 col1" >Amanda</td>
#       <td id="T_d0c46_row1_col2" class="data row1 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Fällman_Amanda">path</a></td>
#       <td id="T_d0c46_row1_col3" class="data row1 col3" >fällmanamanda</td>
#       <td id="T_d0c46_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_d0c46_row1_col5" class="data row1 col5" >15.263195</td>
#       <td id="T_d0c46_row1_col6" class="data row1 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row2" class="row_heading level0 row2" >Axel Feldt</th>
#       <td id="T_d0c46_row2_col0" class="data row2 col0" >Feldt</td>
#       <td id="T_d0c46_row2_col1" class="data row2 col1" >Axel</td>
#       <td id="T_d0c46_row2_col2" class="data row2 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Feldt_Axel">path</a></td>
#       <td id="T_d0c46_row2_col3" class="data row2 col3" >feldtaxel</td>
#       <td id="T_d0c46_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_d0c46_row2_col5" class="data row2 col5" >15.263195</td>
#       <td id="T_d0c46_row2_col6" class="data row2 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row3" class="row_heading level0 row3" >Samuel Flodin</th>
#       <td id="T_d0c46_row3_col0" class="data row3 col0" >Flodin</td>
#       <td id="T_d0c46_row3_col1" class="data row3 col1" >Samuel</td>
#       <td id="T_d0c46_row3_col2" class="data row3 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Flodin_Samuel">path</a></td>
#       <td id="T_d0c46_row3_col3" class="data row3 col3" >flodinsamuel</td>
#       <td id="T_d0c46_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_d0c46_row3_col5" class="data row3 col5" >15.261506</td>
#       <td id="T_d0c46_row3_col6" class="data row3 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row4" class="row_heading level0 row4" >Ida Florin</th>
#       <td id="T_d0c46_row4_col0" class="data row4 col0" >Florin</td>
#       <td id="T_d0c46_row4_col1" class="data row4 col1" >Ida</td>
#       <td id="T_d0c46_row4_col2" class="data row4 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Florin_Ida">path</a></td>
#       <td id="T_d0c46_row4_col3" class="data row4 col3" >florinida</td>
#       <td id="T_d0c46_row4_col4" class="data row4 col4" >True</td>
#       <td id="T_d0c46_row4_col5" class="data row4 col5" >15.261506</td>
#       <td id="T_d0c46_row4_col6" class="data row4 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row5" class="row_heading level0 row5" >Anna Forssgren</th>
#       <td id="T_d0c46_row5_col0" class="data row5 col0" >Forssgren</td>
#       <td id="T_d0c46_row5_col1" class="data row5 col1" >Anna</td>
#       <td id="T_d0c46_row5_col2" class="data row5 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Forssgren_Anna">path</a></td>
#       <td id="T_d0c46_row5_col3" class="data row5 col3" >forssgrenanna</td>
#       <td id="T_d0c46_row5_col4" class="data row5 col4" >True</td>
#       <td id="T_d0c46_row5_col5" class="data row5 col5" >16.978942</td>
#       <td id="T_d0c46_row5_col6" class="data row5 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row6" class="row_heading level0 row6" >Elsa Forssmed</th>
#       <td id="T_d0c46_row6_col0" class="data row6 col0" >Forssmed</td>
#       <td id="T_d0c46_row6_col1" class="data row6 col1" >Elsa</td>
#       <td id="T_d0c46_row6_col2" class="data row6 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Forssmed_Elsa">path</a></td>
#       <td id="T_d0c46_row6_col3" class="data row6 col3" >forssmedelsa</td>
#       <td id="T_d0c46_row6_col4" class="data row6 col4" >True</td>
#       <td id="T_d0c46_row6_col5" class="data row6 col5" >16.978942</td>
#       <td id="T_d0c46_row6_col6" class="data row6 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row7" class="row_heading level0 row7" >Mathias Fredriksson</th>
#       <td id="T_d0c46_row7_col0" class="data row7 col0" >Fredriksson</td>
#       <td id="T_d0c46_row7_col1" class="data row7 col1" >Mathias</td>
#       <td id="T_d0c46_row7_col2" class="data row7 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Fredriksson_Mathias">path</a></td>
#       <td id="T_d0c46_row7_col3" class="data row7 col3" >fredrikssonmathias</td>
#       <td id="T_d0c46_row7_col4" class="data row7 col4" >True</td>
#       <td id="T_d0c46_row7_col5" class="data row7 col5" >15.271930</td>
#       <td id="T_d0c46_row7_col6" class="data row7 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row8" class="row_heading level0 row8" >Vincent Fröberg</th>
#       <td id="T_d0c46_row8_col0" class="data row8 col0" >Fröberg</td>
#       <td id="T_d0c46_row8_col1" class="data row8 col1" >Vincent</td>
#       <td id="T_d0c46_row8_col2" class="data row8 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Fröberg_Vincent">path</a></td>
#       <td id="T_d0c46_row8_col3" class="data row8 col3" >fröbergvincent</td>
#       <td id="T_d0c46_row8_col4" class="data row8 col4" >True</td>
#       <td id="T_d0c46_row8_col5" class="data row8 col5" >15.271930</td>
#       <td id="T_d0c46_row8_col6" class="data row8 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row9" class="row_heading level0 row9" >Sara Furborg</th>
#       <td id="T_d0c46_row9_col0" class="data row9 col0" >Furborg</td>
#       <td id="T_d0c46_row9_col1" class="data row9 col1" >Sara</td>
#       <td id="T_d0c46_row9_col2" class="data row9 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Furborg_Sara">path</a></td>
#       <td id="T_d0c46_row9_col3" class="data row9 col3" >furborgsara</td>
#       <td id="T_d0c46_row9_col4" class="data row9 col4" >True</td>
#       <td id="T_d0c46_row9_col5" class="data row9 col5" >15.261515</td>
#       <td id="T_d0c46_row9_col6" class="data row9 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0c46_level0_row10" class="row_heading level0 row10" >Hampus Gelang</th>
#       <td id="T_d0c46_row10_col0" class="data row10 col0" >Gel

# %%
show(df.loc[df['ok']==True].sort_values(by='family name'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_9575d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >family name</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >dir_path</th>
#       <th class="col_heading level0 col3" >code name</th>
#       <th class="col_heading level0 col4" >has_run_file</th>
#       <th class="col_heading level0 col5" >finishing_time</th>
#       <th class="col_heading level0 col6" >ok</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9575d_level0_row0" class="row_heading level0 row0" >Cornelia Falkhage</th>
#       <td id="T_9575d_row0_col0" class="data row0 col0" >Falkhage</td>
#       <td id="T_9575d_row0_col1" class="data row0 col1" >Cornelia</td>
#       <td id="T_9575d_row0_col2" class="data row0 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Falkhage_Cornelia">path</a></td>
#       <td id="T_9575d_row0_col3" class="data row0 col3" >falkhagecornelia</td>
#       <td id="T_9575d_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_9575d_row0_col5" class="data row0 col5" >15.531188</td>
#       <td id="T_9575d_row0_col6" class="data row0 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row1" class="row_heading level0 row1" >Axel Feldt</th>
#       <td id="T_9575d_row1_col0" class="data row1 col0" >Feldt</td>
#       <td id="T_9575d_row1_col1" class="data row1 col1" >Axel</td>
#       <td id="T_9575d_row1_col2" class="data row1 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Feldt_Axel">path</a></td>
#       <td id="T_9575d_row1_col3" class="data row1 col3" >feldtaxel</td>
#       <td id="T_9575d_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_9575d_row1_col5" class="data row1 col5" >15.263195</td>
#       <td id="T_9575d_row1_col6" class="data row1 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row2" class="row_heading level0 row2" >Samuel Flodin</th>
#       <td id="T_9575d_row2_col0" class="data row2 col0" >Flodin</td>
#       <td id="T_9575d_row2_col1" class="data row2 col1" >Samuel</td>
#       <td id="T_9575d_row2_col2" class="data row2 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Flodin_Samuel">path</a></td>
#       <td id="T_9575d_row2_col3" class="data row2 col3" >flodinsamuel</td>
#       <td id="T_9575d_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_9575d_row2_col5" class="data row2 col5" >15.261506</td>
#       <td id="T_9575d_row2_col6" class="data row2 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row3" class="row_heading level0 row3" >Ida Florin</th>
#       <td id="T_9575d_row3_col0" class="data row3 col0" >Florin</td>
#       <td id="T_9575d_row3_col1" class="data row3 col1" >Ida</td>
#       <td id="T_9575d_row3_col2" class="data row3 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Florin_Ida">path</a></td>
#       <td id="T_9575d_row3_col3" class="data row3 col3" >florinida</td>
#       <td id="T_9575d_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_9575d_row3_col5" class="data row3 col5" >15.261506</td>
#       <td id="T_9575d_row3_col6" class="data row3 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row4" class="row_heading level0 row4" >Anna Forssgren</th>
#       <td id="T_9575d_row4_col0" class="data row4 col0" >Forssgren</td>
#       <td id="T_9575d_row4_col1" class="data row4 col1" >Anna</td>
#       <td id="T_9575d_row4_col2" class="data row4 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Forssgren_Anna">path</a></td>
#       <td id="T_9575d_row4_col3" class="data row4 col3" >forssgrenanna</td>
#       <td id="T_9575d_row4_col4" class="data row4 col4" >True</td>
#       <td id="T_9575d_row4_col5" class="data row4 col5" >16.978942</td>
#       <td id="T_9575d_row4_col6" class="data row4 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row5" class="row_heading level0 row5" >Elsa Forssmed</th>
#       <td id="T_9575d_row5_col0" class="data row5 col0" >Forssmed</td>
#       <td id="T_9575d_row5_col1" class="data row5 col1" >Elsa</td>
#       <td id="T_9575d_row5_col2" class="data row5 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Forssmed_Elsa">path</a></td>
#       <td id="T_9575d_row5_col3" class="data row5 col3" >forssmedelsa</td>
#       <td id="T_9575d_row5_col4" class="data row5 col4" >True</td>
#       <td id="T_9575d_row5_col5" class="data row5 col5" >16.978942</td>
#       <td id="T_9575d_row5_col6" class="data row5 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row6" class="row_heading level0 row6" >Mathias Fredriksson</th>
#       <td id="T_9575d_row6_col0" class="data row6 col0" >Fredriksson</td>
#       <td id="T_9575d_row6_col1" class="data row6 col1" >Mathias</td>
#       <td id="T_9575d_row6_col2" class="data row6 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Fredriksson_Mathias">path</a></td>
#       <td id="T_9575d_row6_col3" class="data row6 col3" >fredrikssonmathias</td>
#       <td id="T_9575d_row6_col4" class="data row6 col4" >True</td>
#       <td id="T_9575d_row6_col5" class="data row6 col5" >15.271930</td>
#       <td id="T_9575d_row6_col6" class="data row6 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row7" class="row_heading level0 row7" >Vincent Fröberg</th>
#       <td id="T_9575d_row7_col0" class="data row7 col0" >Fröberg</td>
#       <td id="T_9575d_row7_col1" class="data row7 col1" >Vincent</td>
#       <td id="T_9575d_row7_col2" class="data row7 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Fröberg_Vincent">path</a></td>
#       <td id="T_9575d_row7_col3" class="data row7 col3" >fröbergvincent</td>
#       <td id="T_9575d_row7_col4" class="data row7 col4" >True</td>
#       <td id="T_9575d_row7_col5" class="data row7 col5" >15.271930</td>
#       <td id="T_9575d_row7_col6" class="data row7 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row8" class="row_heading level0 row8" >Sara Furborg</th>
#       <td id="T_9575d_row8_col0" class="data row8 col0" >Furborg</td>
#       <td id="T_9575d_row8_col1" class="data row8 col1" >Sara</td>
#       <td id="T_9575d_row8_col2" class="data row8 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Furborg_Sara">path</a></td>
#       <td id="T_9575d_row8_col3" class="data row8 col3" >furborgsara</td>
#       <td id="T_9575d_row8_col4" class="data row8 col4" >True</td>
#       <td id="T_9575d_row8_col5" class="data row8 col5" >15.261515</td>
#       <td id="T_9575d_row8_col6" class="data row8 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row9" class="row_heading level0 row9" >Amanda Fällman</th>
#       <td id="T_9575d_row9_col0" class="data row9 col0" >Fällman</td>
#       <td id="T_9575d_row9_col1" class="data row9 col1" >Amanda</td>
#       <td id="T_9575d_row9_col2" class="data row9 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Fällman_Amanda">path</a></td>
#       <td id="T_9575d_row9_col3" class="data row9 col3" >fällmanamanda</td>
#       <td id="T_9575d_row9_col4" class="data row9 col4" >True</td>
#       <td id="T_9575d_row9_col5" class="data row9 col5" >15.263195</td>
#       <td id="T_9575d_row9_col6" class="data row9 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9575d_level0_row10" class="row_heading level0 row10" >Hampus Gelang</th>
#       <td id="T_9575d_row10_col0" class="data row10 col0" >Gel

# %%
show(df.loc[df['ok']!=True])
# Out:
# <style type="text/css">
# </style>
# <table id="T_da520_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >family name</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >dir_path</th>
#       <th class="col_heading level0 col3" >code name</th>
#       <th class="col_heading level0 col4" >has_run_file</th>
#       <th class="col_heading level0 col5" >finishing_time</th>
#       <th class="col_heading level0 col6" >ok</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da520_level0_row0" class="row_heading level0 row0" >Zahran Saeed Ghazy</th>
#       <td id="T_da520_row0_col0" class="data row0 col0" >Ghazy</td>
#       <td id="T_da520_row0_col1" class="data row0 col1" >Zahran Saeed</td>
#       <td id="T_da520_row0_col2" class="data row0 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Ghazy_Zahran Saeed">path</a></td>
#       <td id="T_da520_row0_col3" class="data row0 col3" >ghazyzahran saeed</td>
#       <td id="T_da520_row0_col4" class="data row0 col4" >False</td>
#       <td id="T_da520_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_da520_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_da520_level0_row1" class="row_heading level0 row1" >Karl-Axel Gustafsson</th>
#       <td id="T_da520_row1_col0" class="data row1 col0" >Gustafsson</td>
#       <td id="T_da520_row1_col1" class="data row1 col1" >Karl-Axel</td>
#       <td id="T_da520_row1_col2" class="data row1 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Gustafsson_Karl-Axel">path</a></td>
#       <td id="T_da520_row1_col3" class="data row1 col3" >gustafssonkarl-axel</td>
#       <td id="T_da520_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_da520_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_da520_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_da520_level0_row2" class="row_heading level0 row2" >Hans Hallbäck</th>
#       <td id="T_da520_row2_col0" class="data row2 col0" >Hallbäck</td>
#       <td id="T_da520_row2_col1" class="data row2 col1" >Hans</td>
#       <td id="T_da520_row2_col2" class="data row2 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Hallbäck_Hans">path</a></td>
#       <td id="T_da520_row2_col3" class="data row2 col3" >hallbäckhans</td>
#       <td id="T_da520_row2_col4" class="data row2 col4" >False</td>
#       <td id="T_da520_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_da520_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_da520_level0_row3" class="row_heading level0 row3" >Wilmer Helland</th>
#       <td id="T_da520_row3_col0" class="data row3 col0" >Helland</td>
#       <td id="T_da520_row3_col1" class="data row3 col1" >Wilmer</td>
#       <td id="T_da520_row3_col2" class="data row3 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Helland_Wilmer">path</a></td>
#       <td id="T_da520_row3_col3" class="data row3 col3" >hellandwilmer</td>
#       <td id="T_da520_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_da520_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_da520_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.sort_values(by='finishing_time', inplace=True)
show(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c089_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >family name</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >dir_path</th>
#       <th class="col_heading level0 col3" >code name</th>
#       <th class="col_heading level0 col4" >has_run_file</th>
#       <th class="col_heading level0 col5" >finishing_time</th>
#       <th class="col_heading level0 col6" >ok</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c089_level0_row0" class="row_heading level0 row0" >Gustav Haller</th>
#       <td id="T_5c089_row0_col0" class="data row0 col0" >Haller</td>
#       <td id="T_5c089_row0_col1" class="data row0 col1" >Gustav</td>
#       <td id="T_5c089_row0_col2" class="data row0 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Haller_Gustav">path</a></td>
#       <td id="T_5c089_row0_col3" class="data row0 col3" >hallergustav</td>
#       <td id="T_5c089_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_5c089_row0_col5" class="data row0 col5" >15.064779</td>
#       <td id="T_5c089_row0_col6" class="data row0 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row1" class="row_heading level0 row1" >Oskar Haapalo</th>
#       <td id="T_5c089_row1_col0" class="data row1 col0" >Haapalo</td>
#       <td id="T_5c089_row1_col1" class="data row1 col1" >Oskar</td>
#       <td id="T_5c089_row1_col2" class="data row1 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Haapalo_Oskar">path</a></td>
#       <td id="T_5c089_row1_col3" class="data row1 col3" >haapalooskar</td>
#       <td id="T_5c089_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_5c089_row1_col5" class="data row1 col5" >15.064779</td>
#       <td id="T_5c089_row1_col6" class="data row1 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row2" class="row_heading level0 row2" >Amanda Gustafsson</th>
#       <td id="T_5c089_row2_col0" class="data row2 col0" >Gustafsson</td>
#       <td id="T_5c089_row2_col1" class="data row2 col1" >Amanda</td>
#       <td id="T_5c089_row2_col2" class="data row2 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Gustafsson_Amanda">path</a></td>
#       <td id="T_5c089_row2_col3" class="data row2 col3" >gustafssonamanda</td>
#       <td id="T_5c089_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_5c089_row2_col5" class="data row2 col5" >15.168952</td>
#       <td id="T_5c089_row2_col6" class="data row2 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row3" class="row_heading level0 row3" >Adam Gunnarsson</th>
#       <td id="T_5c089_row3_col0" class="data row3 col0" >Gunnarsson</td>
#       <td id="T_5c089_row3_col1" class="data row3 col1" >Adam</td>
#       <td id="T_5c089_row3_col2" class="data row3 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Gunnarsson_Adam">path</a></td>
#       <td id="T_5c089_row3_col3" class="data row3 col3" >gunnarssonadam</td>
#       <td id="T_5c089_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_5c089_row3_col5" class="data row3 col5" >15.168952</td>
#       <td id="T_5c089_row3_col6" class="data row3 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row4" class="row_heading level0 row4" >Samuel Flodin</th>
#       <td id="T_5c089_row4_col0" class="data row4 col0" >Flodin</td>
#       <td id="T_5c089_row4_col1" class="data row4 col1" >Samuel</td>
#       <td id="T_5c089_row4_col2" class="data row4 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Flodin_Samuel">path</a></td>
#       <td id="T_5c089_row4_col3" class="data row4 col3" >flodinsamuel</td>
#       <td id="T_5c089_row4_col4" class="data row4 col4" >True</td>
#       <td id="T_5c089_row4_col5" class="data row4 col5" >15.261506</td>
#       <td id="T_5c089_row4_col6" class="data row4 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row5" class="row_heading level0 row5" >Ida Florin</th>
#       <td id="T_5c089_row5_col0" class="data row5 col0" >Florin</td>
#       <td id="T_5c089_row5_col1" class="data row5 col1" >Ida</td>
#       <td id="T_5c089_row5_col2" class="data row5 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Florin_Ida">path</a></td>
#       <td id="T_5c089_row5_col3" class="data row5 col3" >florinida</td>
#       <td id="T_5c089_row5_col4" class="data row5 col4" >True</td>
#       <td id="T_5c089_row5_col5" class="data row5 col5" >15.261506</td>
#       <td id="T_5c089_row5_col6" class="data row5 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row6" class="row_heading level0 row6" >Hampus Gelang</th>
#       <td id="T_5c089_row6_col0" class="data row6 col0" >Gelang</td>
#       <td id="T_5c089_row6_col1" class="data row6 col1" >Hampus</td>
#       <td id="T_5c089_row6_col2" class="data row6 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Gelang_Hampus">path</a></td>
#       <td id="T_5c089_row6_col3" class="data row6 col3" >gelanghampus</td>
#       <td id="T_5c089_row6_col4" class="data row6 col4" >True</td>
#       <td id="T_5c089_row6_col5" class="data row6 col5" >15.261515</td>
#       <td id="T_5c089_row6_col6" class="data row6 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row7" class="row_heading level0 row7" >Sara Furborg</th>
#       <td id="T_5c089_row7_col0" class="data row7 col0" >Furborg</td>
#       <td id="T_5c089_row7_col1" class="data row7 col1" >Sara</td>
#       <td id="T_5c089_row7_col2" class="data row7 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Furborg_Sara">path</a></td>
#       <td id="T_5c089_row7_col3" class="data row7 col3" >furborgsara</td>
#       <td id="T_5c089_row7_col4" class="data row7 col4" >True</td>
#       <td id="T_5c089_row7_col5" class="data row7 col5" >15.261515</td>
#       <td id="T_5c089_row7_col6" class="data row7 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row8" class="row_heading level0 row8" >Amanda Fällman</th>
#       <td id="T_5c089_row8_col0" class="data row8 col0" >Fällman</td>
#       <td id="T_5c089_row8_col1" class="data row8 col1" >Amanda</td>
#       <td id="T_5c089_row8_col2" class="data row8 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Fällman_Amanda">path</a></td>
#       <td id="T_5c089_row8_col3" class="data row8 col3" >fällmanamanda</td>
#       <td id="T_5c089_row8_col4" class="data row8 col4" >True</td>
#       <td id="T_5c089_row8_col5" class="data row8 col5" >15.263195</td>
#       <td id="T_5c089_row8_col6" class="data row8 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row9" class="row_heading level0 row9" >Axel Feldt</th>
#       <td id="T_5c089_row9_col0" class="data row9 col0" >Feldt</td>
#       <td id="T_5c089_row9_col1" class="data row9 col1" >Axel</td>
#       <td id="T_5c089_row9_col2" class="data row9 col2" ><a href="file:///E:\dev\TME136-Programming-and-algorithms\2021\assignments\assignment1\matlab\students\assignments\Feldt_Axel">path</a></td>
#       <td id="T_5c089_row9_col3" class="data row9 col3" >feldtaxel</td>
#       <td id="T_5c089_row9_col4" class="data row9 col4" >True</td>
#       <td id="T_5c089_row9_col5" class="data row9 col5" >15.263195</td>
#       <td id="T_5c089_row9_col6" class="data row9 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5c089_level0_row10" class="row_heading level0 row10" >Matilda Graad</th>
#       <td id="T_5c089_row10_col0" class="data row10 col0" >Graad</td>
#       <td id="T_5c08

# %%
df.to_csv('Martin_Alexandersson_finishing_times.csv', sep=';', encoding='cp1252')
